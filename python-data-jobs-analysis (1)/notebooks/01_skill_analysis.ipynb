# %% [markdown]
# # Investigating Top Skills in Data Science
# Interactive walkthrough. The same logic lives in `src/` as runnable scripts.

# %%
import sys; sys.path.insert(0, '../src')
from skill_demand import load, top_skills
from skill_trends import monthly_trend, plot as plot_trend
from salary_analysis import skill_salary, plot as plot_salary
from optimal_skills import optimal_table, plot as plot_optimal
df = load()
df.head()

# %%
top_skills(df, 'Data Analyst')

# %%
plot_trend(monthly_trend(df, 'Data Analyst'), 'Data Analyst')

# %%
plot_salary(skill_salary(df, 'Data Analyst'), 'Data Analyst')

# %%
tbl = optimal_table(df, 'Data Analyst')
plot_optimal(tbl, 'Data Analyst')
tbl
